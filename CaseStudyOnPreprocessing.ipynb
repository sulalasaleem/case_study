# %% [markdown]
# # Case Study On Preprocessing

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the dataset into python environment and Check the basic details of the dataset

# %%
data=pd.read_csv('titanic_dataset.csv')
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Make ‘PassengerId’ as the index column

# %%
data.set_index('PassengerId',inplace=True)

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # Fill in all the missing values present in all the columns in the dataset

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='Pclass',y="Age",data=data,palette='winter')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
def fill_age(cols):
    Age=cols[0]
    Pclass=cols[1]
    
    if pd.isnull(Age):
        if Pclass==1:
            return 37
        elif Pclass==2:
            return 29
        else:
            return 24
        
    else:
        return Age

# %%
data['Age']=data[['Age','Pclass']].apply(fill_age,axis=1)

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data.drop('Cabin',axis=1,inplace=True)

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# # Check and handle outliers in at least 3 columns in the dataset

# %%
plt.boxplot(data['SibSp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ccc0619d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ccc072130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ccc061640>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ccc072850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ccc072be0>],
#  'means': []}

# %%
Q1=data.SibSp.quantile(0.25)
Q3=data.SibSp.quantile(0.75)
Q1, Q3
# Out:
# (0.0, 1.0)

# %%
IQR=Q3-Q1 
IQR
# Out:
# 1.0

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (-1.5, 2.5)

# %%
data[(data.SibSp<lower_limit)|(data.SibSp>upper_limit)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 8                   0       3
# 17                  0       3
# 25                  0       3
# 28                  0       1
# 51                  0       3
# 60                  0       3
# 64                  0       3
# 69                  1       3
# 72                  0       3
# 86                  1       3
# 89                  1       1
# 120                 0       3
# 160                 0       3
# 165                 0       3
# 172                 0       3
# 177                 0       3
# 181                 0       3
# 183                 0       3
# 202                 0       3
# 230                 0       3
# 234                 1       3
# 262                 1       3
# 267                 0       3
# 279                 0       3
# 325                 0       3
# 342                 1       1
# 375                 0       3
# 387                 0       3
# 410                 0       3
# ...

# %%
data_no_outliers=data[(data.SibSp>lower_limit)&(data.SibSp<upper_limit)]

# %%
data_no_outliers
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
plt.boxplot(data_no_outliers['SibSp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ccc0e7b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ccc0f4280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ccc0db610>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ccc0f49a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ccc0f4d30>],
#  'means': []}

# %%
plt.boxplot(data_no_outliers['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ccc15e760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ccc15ee80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ccc15e3d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ccc1695e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ccc169970>],
#  'means': []}

# %%
Q11=data_no_outliers.Fare.quantile(0.25)
Q33=data_no_outliers.Fare.quantile(0.75)
Q11, Q33
# Out:
# (7.8958, 29.7)

# %%
IQR1=Q33-Q11 
IQR1
# Out:
# 21.804199999999998

# %%
lower_limit1=Q11-1.5*IQR1
upper_limit1=Q33+1.5*IQR1
lower_limit1,upper_limit1
# Out:
# (-24.810499999999998, 62.4063)

# %%
data_no_outliers[(data_no_outliers.Fare<lower_limit1)|(data_no_outliers.Fare>upper_limit1)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 32                  1       1
# 35                  0       1
# 53                  1       1
# 63                  0       1
# ...               ...     ...
# 821                 1       1
# 836                 1       1
# 850                 1       1
# 857                 1       1
# 880                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)  female  37.0
# 35                                     Meyer, Mr. Edgar Joseph    male  28.0
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# 63                                 Harris, Mr. Henry Birkhardt    male  45.0
# ...                                                        ...     ...   ...
# ...

# %%
data_no_outliers=data_no_outliers[(data_no_outliers.Fare>lower_limit1)&(data_no_outliers.Fare<upper_limit1)]

# %%
plt.boxplot(data_no_outliers['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ccc1c6dc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ccc1d3520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ccc1c6a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ccc1d3c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ccc1d3fd0>],
#  'means': []}

# %%
plt.boxplot(data_no_outliers['Pclass'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ccc3ba250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ccc3ba970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ccc3ade80>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ccc3c80d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ccc3c8460>],
#  'means': []}

# %%
Q12=data_no_outliers.Pclass.quantile(0.25)
Q32=data_no_outliers.Pclass.quantile(0.75)
Q12, Q32
# Out:
# (2.0, 3.0)

# %%
IQR2=Q32-Q12 
IQR2
# Out:
# 1.0

# %%
lower_limit2=Q12-1.5*IQR2
upper_limit2=Q32+1.5*IQR2
lower_limit2,upper_limit2
# Out:
# (0.5, 4.5)

# %%
data_no_outliers[(data_no_outliers.Pclass<lower_limit2)|(data_no_outliers.Pclass>upper_limit2)]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %% [markdown]
# No Outliers

# %%
plt.boxplot(data_no_outliers['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ccc42d760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ccc42de80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ccc42d3d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ccc4375e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ccc437970>],
#  'means': []}

# %%
Q12=data_no_outliers.Age.quantile(0.25)
Q32=data_no_outliers.Age.quantile(0.75)
Q12, Q32
# Out:
# (23.0, 36.0)

# %%
IQR2=Q32-Q12 
IQR2
# Out:
# 13.0

# %%
lower_limit2=Q12-1.5*IQR2
upper_limit2=Q32+1.5*IQR2
lower_limit2,upper_limit2
# Out:
# (3.5, 55.5)

# %%
data_no_outliers[(data_no_outliers.Age<lower_limit2)|(data_no_outliers.Age>upper_limit2)]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 12                  1       1                  Bonnell, Miss. Elizabeth
# 34                  0       2                     Wheadon, Mr. Edward H
# 44                  1       2  Laroche, Miss. Simonne Marie Anne Andree
# 55                  0       1            Ostby, Mr. Engelhart Cornelius
# 79                  1       2             Caldwell, Master. Alden Gates
# 95                  0       3                         Coxon, Mr. Daniel
# 97                  0       1                 Goldschmidt, Mr. George B
# 117                 0       3                      Connors, Mr. Patrick
# 171                 0       1                 Van der hoef, Mr. Wyckoff
# 173                 1       3              Johnson, Miss. Eleanor Ileen
# 175                 0       1                   Smith, Mr. James Clinch
# 184                 1       2                 Becker, Master. Richard F
# ...

# %%
data_no_outliers=data_no_outliers[(data_no_outliers.Age>lower_limit2)&(data_no_outliers.Age<upper_limit2)]

# %%
data_no_outliers
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
plt.boxplot(data_no_outliers['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ccc4a6070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ccc4a6790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ccc497ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ccc4a6eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ccc4b3280>],
#  'means': []}

# %%
data_no_outliers.drop('Name',inplace=True,axis=1)

# %%
data_no_outliers.drop('Ticket',inplace=True,axis=1)

# %%
data_no_outliers
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S
# 6                   0       3    male  24.0      0      0   8.4583        Q
# ...               ...     ...     ...   ...    ...    ...      ...      ...
# 887                 0       2    male  27.0      0      0  13.0000        S
# 888                 1       1  female  19.0      0      0  30.0000        S
# 889                 0       3  female  24.0      1      2  23.4500        S
# 890                 1       1    male  26.0      0      0  30.0000        C
# 891                 0       3    male  32.0      0      0   7.7500        Q
#
# [687 rows x 8 columns]

# %% [markdown]
# # Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
data_no_outliers.shape
# Out:
# (687, 8)

# %%
df=pd.get_dummies(data_no_outliers)

# %%
df
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500           0
# 3                   1       3  26.0      0      0   7.9250           1
# 4                   1       1  35.0      1      0  53.1000           1
# 5                   0       3  35.0      0      0   8.0500           0
# 6                   0       3  24.0      0      0   8.4583           0
# ...               ...     ...   ...    ...    ...      ...         ...
# 887                 0       2  27.0      0      0  13.0000           0
# 888                 1       1  19.0      0      0  30.0000           1
# 889                 0       3  24.0      1      2  23.4500           1
# 890                 1       1  26.0      0      0  30.0000           0
# 891                 0       3  32.0      0      0   7.7500           0
#
#              Sex_male  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# ...

# %%
y=df['Survived']
x=df.drop(['Survived','Fare'],axis=1)

# %%
from sklearn import preprocessing

# %%
x.describe()
# Out:
#            Pclass         Age       SibSp       Parch  Sex_female    Sex_male  \
# count  687.000000  687.000000  687.000000  687.000000  687.000000  687.000000
# mean     2.491994   28.513828    0.267831    0.263464    0.312955    0.687045
# std      0.726132    9.779092    0.498860    0.751396    0.464034    0.464034
# min      1.000000    4.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   24.000000    0.000000    0.000000    0.000000    0.000000
# 50%      3.000000   26.000000    0.000000    0.000000    0.000000    1.000000
# 75%      3.000000   35.000000    0.000000    0.000000    1.000000    1.000000
# max      3.000000   55.000000    2.000000    6.000000    1.000000    1.000000
#
#        Embarked_C  Embarked_Q  Embarked_S
# count  687.000000  687.000000  687.000000
# mean     0.149927    0.098981    0.751092
# std      0.357260    0.298854    0.432696
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000
# ...

# %%
min_max=preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
x=min_max.fit_transform(x)

# %%
x=pd.DataFrame(x)

# %%
x.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  687.000000  687.000000  687.000000  687.000000  687.000000  687.000000
# mean     0.745997    0.480663    0.133916    0.043911    0.312955    0.687045
# std      0.363066    0.191747    0.249430    0.125233    0.464034    0.464034
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.392157    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.431373    0.000000    0.000000    0.000000    1.000000
# 75%      1.000000    0.607843    0.000000    0.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7           8
# count  687.000000  687.000000  687.000000
# mean     0.149927    0.098981    0.751092
# std      0.357260    0.298854    0.432696
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000
# ...
